# %% [markdown]
# **Cell 1: Pipeline Setup and Prediction Generation**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Load our curated student records dataset
df = pd.read_csv("task-5_data_cleaning.csv")
df = df.drop_duplicates()
df['Attendance_Pct'] = df['Attendance_Pct'].fillna(df['Attendance_Pct'].mean())
df['Midterm_Score'] = df['Midterm_Score'].fillna(df['Midterm_Score'].mean())

# Define variables using the true independent feature in our dataset 
X = df[['Midterm_Score']]
y = df['Final_Score']

# Split data using fixed random state for structural consistency
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Instantiate and fit the model estimator
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Generate predictions on the test split
y_pred = regressor.predict(X_test)
print("Validation arrays ready for metric extraction! ✓")
# Out:
# Validation arrays ready for metric extraction! ✓

# %% [markdown]
# **Cell 2: Evaluation Metric Extraction**

# %%
# Calculate statistical evaluation parameters
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("--- Model Performance Metrics ---")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2) Score: {r2:.4f}")
# Out:
# --- Model Performance Metrics ---
# Mean Absolute Error (MAE): 7.4108
# Mean Squared Error (MSE): 59.5540
# Root Mean Squared Error (RMSE): 7.7171
# R-squared (R2) Score: -8.5286
