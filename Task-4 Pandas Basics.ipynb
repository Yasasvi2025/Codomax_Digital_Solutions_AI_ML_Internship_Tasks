# %% [markdown]
# **Cell 1: Generate the Mock Dataset**

# %%
import csv

# Create the data rows
data = [
    ["Student_ID", "Name", "Department", "Attendance_Pct", "Midterm_Score", "Final_Score"],
    ["STU_101", "Aarav Sharma", "Computer Science", 92.5, 78, 85],
    ["STU_102", "Diya Patel", "Data Science", 88.0, 92, 90],
    ["STU_103", "Vihaan Gupta", "Computer Science", 74.2, 65, 72],
    ["STU_104", "Ananya Reddy", "Artificial Intelligence", 95.0, 88, 94],
    ["STU_105", "Kabir Verma", "Data Science", 81.5, 45, 58],
    ["STU_106", "Sai Joshi", "Artificial Intelligence", 89.8, 84, 82],
    ["STU_107", "Isha Malhotra", "Computer Science", 91.0, 70, 79]
]

# Write to CSV
with open("student_scores.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerows(data)

print("Dataset 'student_scores.csv' generated successfully!")
# Out:
# Dataset 'student_scores.csv' generated successfully!

# %% [markdown]
# **Cell 2: Import Pandas & Load the Dataset**

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("student_scores.csv")
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %% [markdown]
# **Cell 3: Head & Tail Exploration**

# %%
print("--- First 3 Rows ---")
print(df.head(3))

print("\n--- Last 2 Rows ---")
print(df.tail(2))
# Out:
# --- First 3 Rows ---
#   Student_ID          Name        Department  Attendance_Pct  Midterm_Score  \
# 0    STU_101  Aarav Sharma  Computer Science            92.5             78
# 1    STU_102    Diya Patel      Data Science            88.0             92
# 2    STU_103  Vihaan Gupta  Computer Science            74.2             65
#
#    Final_Score
# 0           85
# 1           90
# 2           72
#
# --- Last 2 Rows ---
#   Student_ID           Name               Department  Attendance_Pct  \
# 5    STU_106      Sai Joshi  Artificial Intelligence            89.8
# 6    STU_107  Isha Malhotra         Computer Science            91.0
#
#    Midterm_Score  Final_Score
# 5             84           82
# 6             70           79

# %% [markdown]
# **Cell 4: Structural Attributes (Shape, Columns, Index)**

# %%
print("Dataset Shape (Rows, Columns):", df.shape)
print("\nColumn Labels:", df.columns.tolist())
print("\nIndex Properties:", df.index)
# Out:
# Dataset Shape (Rows, Columns): (7, 6)
#
# Column Labels: ['Student_ID', 'Name', 'Department', 'Attendance_Pct', 'Midterm_Score', 'Final_Score']
#
# Index Properties: RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# **Cell 5: Dataset Summary Information**

# %%
print("--- Structural Information Summary ---")
df.info()
# Out:
# --- Structural Information Summary ---
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      7 non-null      str
#  1   Name            7 non-null      str
#  2   Department      7 non-null      str
#  3   Attendance_Pct  7 non-null      float64
#  4   Midterm_Score   7 non-null      int64
#  5   Final_Score     7 non-null      int64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 714.0 bytes
